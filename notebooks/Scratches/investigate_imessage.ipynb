# %%
import sqlite3
import pandas as pd

# %%
con = sqlite3.connect('../data/raw/imessage/chat.db')

# %%
sql = "SELECT name FROM sqlite_master WHERE type='table'"
tables = pd.read_sql(sql, con)

# %%
tables
# Out:
#                          name
# 0   _SqliteDatabaseProperties
# 1                     message
# 2             sqlite_sequence
# 3                        chat
# 4                  attachment
# 5                      handle
# 6     message_attachment_join
# 7            chat_handle_join
# 8           chat_message_join
# 9            deleted_messages
# 10      sync_deleted_messages
# 11    message_processing_task
# 12         sync_deleted_chats
# 13   sync_deleted_attachments
# 14                    kvtable
# 15               sqlite_stat1

# %%
sql = "SELECT * FROM message"
messages = pd.read_sql(sql, con)
messages.tail()
# Out:
#        ROWID                                  guid  \
# 31061  31099  E4A59581-BFEE-43B3-B436-55C37C07465A
# 31062  31100  70984ABC-F655-4D68-A4DC-496C7E8833F2
# 31063  31101  C8C4EFCA-D019-4E59-882C-F6A37F4B06A2
# 31064  31102  F71C80A5-ECAE-46C9-A39B-5688C0501A14
# 31065  31103  9D23696F-7BF5-471E-862C-83DB88118180
#
#                                                     text  replace  \
# 31061                                        Such a faff        0
# 31062  And I’m quite jealous of all the people who’ll...        0
# 31063             Loo roll shortages will only get worse        0
# 31064  Then you’ll really need to be careful about wa...        0
# 31065  Laughed at “Then you’ll really need to be care...        0
#
#       service_center  handle_id subject country  \
# 31061           None         62    None    None
# 31062           None         62    None    None
# 31063           None         62    None    None
# 31064           None         62    None    None
# 31065           None         62    None    None
#
#                                           attributedBody  version  ...  \
# 31061  b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84...       10  ...
# 31062  b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84...       10  ...
# 31063  b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84...       10  ...
# 31064  b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84...       10  ...
# 31065  b'\x04\x0bstreamtyped\x81\xe8\x03\x84\x01@\x84...       10  ...
#
#        ck_record_id ck_record_change_tag destination_caller_id  \
# 31061                                            +447792409067
# 31062                                            +447792409067
# 31063                                            +447792409067
# 31064                                            +447792409067
# 31065          None                 None         +447792409067
#
#       sr_ck_sync_state  sr_ck_record_id  sr_ck_record_change_tag  is_corrupt  \
# 31061                0                                                     0
# 31062                0                                                     0
# 31063                0                                                     0
# 31064                0                                                     0
# 31065                0             None                     None           0
#
#                               reply_to_guid  sort_id  is_spam
# 31061  F6F5FCB3-EC33-40FF-A410-4055A87B5F1F        0        0
# 31062  E4A59581-BFEE-43B3-B436-55C37C07465A        0        0
# 31063  70984ABC-F655-4D68-A4DC-496C7E8833F2        0        0
# 31064  C8C4EFCA-D019-4E59-882C-F6A37F4B06A2        0        0
# 31065  F71C80A5-ECAE-46C9-A39B-5688C0501A14        0        0
#
# [5 rows x 71 columns]

# %%
sql = "SELECT * from chat"
chat = pd.read_sql(sql, con)
chat.tail()
# Out:
#      ROWID                      guid  style  state  \
# 103    105  iMessage;-;+447717844213     45      3
# 104    106       SMS;-;+447717844213     45      3
# 105    107  iMessage;-;+447751870091     45      3
# 106    108  iMessage;-;+447792955159     45      3
# 107    109  iMessage;-;+447522912340     45      3
#
#                                account_id  \
# 103  3A624DF0-08E5-4D45-8EFD-05EFC3C840D9
# 104  C5592D54-9D20-4106-AEA6-EFE5D6228C55
# 105  3A624DF0-08E5-4D45-8EFD-05EFC3C840D9
# 106  3A624DF0-08E5-4D45-8EFD-05EFC3C840D9
# 107  3A624DF0-08E5-4D45-8EFD-05EFC3C840D9
#
#                                             properties chat_identifier  \
# 103  b'bplist00\xd6\x01\x02\x03\x04\x05\x06\x07\x08...   +447717844213
# 104  b'bplist00\xd1\x01\x02_\x10#CKChatPreviousAcco...   +447717844213
# 105  b'bplist00\xd4\x01\x02\x03\x04\x05\x06\t\nRpv_...   +447751870091
# 106  b'bplist00\xd3\x01\x02\x03\x04\x07\x08_\x10%co...   +447792955159
# 107  b'bplist00\xd4\x01\x02\x03\x04\x05\x06\x07\nRp...   +447522912340
#
#     service_name room_name             account_login  ...  ck_sync_state  \
# 103     iMessage      None  E:edward.r.rees@zoho.com  ...              0
# 104          SMS      None                        E:  ...              0
# 105     iMessage      None  E:edward.r.rees@zoho.com  ...              0
# 106     iMessage      None  E:edward.r.rees@zoho.com  ...              0
# 107     iMessage      None  E:edward.r.rees@zoho.com  ...              0
#
#     last_read_message_timestamp ck_record_system_property_blob  \
# 103          594567908692263936                           None
# 104                           0                           None
# 105          605890938003845632                           None
# 106          602273171228137728                           None
# 107          605873639485800704                           None
#
#                             original_group_id  sr_server_change_token  \
# 103      A8BF353A-18A3-4277-B333-91D95C2E33D8
# 104  56A3B88DCA1262711F8205BAD8D253584E4078DA
# 105      BB22956F-73C9-40ED-B4AA-CC93F4B2972F
# 106      D22686AB-9CBD-423C-8B9A-3BC7FDC8B5E5
# 107      91824DD6-E037-48AF-9A9A-2E9D27ACA486
#
#      sr_ck_sync_state cloudkit_record_id sr_cloudkit_record_id  \
# 103                 0
# 104                 0
# 105                 0
# 106                 0
# 107                 0
#
#      last_addressed_sim_id  is_blackholed
# 103                   None              0
# 104                   None              0
# 105                   None              0
# 106                   None              0
# 107                   None              0
#
# [5 rows x 28 columns]
